# %% [markdown]
# <a href="https://colab.research.google.com/github/hyejin9912/class2022Spring/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries

# %% [markdown]
# pandas: 엑셀파일이라고 생각하면 됨.
#
# pandas 불러오기. 내 컴퓨터에 깔려있다고 가정한 채 불러오는 것.

# %%
import pandas as pd

# %% [markdown]
# ### Loading csv file

# %%
df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# pandas 안에 있는 read_csv라는 function은 뭐를 하는가?
#
# csv 파일(엑셀파일)을 넣으면, 웹사이트 주소를 불러와도 됨.
#
# comma로 정보를 seperate했다.
#
# 텍스트로도, 엑셀로도 불러올 수 있다.
#
# 이 웹사이트(url)에 있는 csv 파일을 read 하고 df라는 변수로 받음.
#
# 변수를 그냥 적으면 print가 적용됨.
#
# 첫 row에는 각각의 컬럼의 정보가 있음. 총 9개의 컬럼. row는 17000개.
#
# 이거를 데이터 프레임이라고 함. 엑셀 형식으로 생긴 것을 데이터 프레임이라고 부름.

# %%
print(df.size); print(df.ndim); print(df.shape)
# Out:
# 153000
# 2
# (17000, 9)

# %% [markdown]
# df 변수에 대해 상세정보를 볼 수 있음.
#
# size: 17000*9 해서 총 153000개의 셀들로 이루어져 있다.
#
# ndim: 차원이 몇 차원이냐? 행, 열 2차원. 17000*9의 차원.
#
# shape: (17000, 9)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# 기본적인 통계정보 뽑아줌.
#
# 총 몇 개인가
#
# 평균
#
# 표준편차
#
# 최소
#
# 미니멈에서 25프로/50프로/70프로
#
# 최대

# %% [markdown]
# ### Saving to CSV

# %%
df.to_csv('california_housing_train.csv')

# %% [markdown]
# 위의 상태는 변수의 형태인데, 파일로 저장을 하고 싶을 때 옆에 파일이 만들어짐. 구글 컴퓨터기 때문에 여기서 내 컴퓨터로 다운로드 하면 됨.
#
# 위에서 파일의 형태가 데이터프레임이라는 변수의 형태로 read해서 다시 파일의 형태로 바꿀 수 있다.
#
# csv형태가 엑셀보다 더 general.

# %% [markdown]
# ### Constructing a DataFrame using dict

# %%
# Some input data - a small sample of the iris dataset
data = {'sepal_length': [6.9, 6.9, 4.8, 5.4, 4.6],
        'sepal_width': [3.2, 3.1, 3.4, 3.0, 3.6],
        'petal_length': [5.7, 5.1, 1.9, 4.5, 1.0],
        'petal_width': [2.3, 2.3, 0.2, 1.5, 0.2],
        'species': ['virginica', 'virginica', 'setosa', 'versicolor', 'setosa']}

df = pd.DataFrame(data)
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa

# %% [markdown]
# 정보를 가지고 처음부터 만들어쓸 순 없을까?
#
# dict. 중괄호, 안에 들어있는 내용이 구분됨.
#
# 각 아이템은 key 와 value로 구분, 총 5개가 정의되어 있음.
#
# 개수가 맞아야 함. 5개씩.
#
# 데이타를 먼저 dict로 만든다.
#
# 다음에 dict를 pd. Dataframe 으로 만든다.
#
# 엑셀 파일과 형태가 똑같음.
#
# csv 읽을 수 있고, 파일 내부에서 직접 다 적어서 만들어줄 수도 있음.

# %% [markdown]
# ### Constructing a DataFrame using pd.Series

# %%
sepal_length = pd.Series([6.9, 6.9, 4.8, 5.4, 4.6])
sepal_width = pd.Series([3.2, 3.1, 3.4, 3.0, 3.6])
petal_length = pd.Series([5.7, 5.1, 1.9, 4.5, 1.0])
petal_width = pd.Series([2.3, 2.3, 0.2, 1.5, 0.2])
species = pd.Series(['virginica', 'virginica', 'setosa', 'versicolor', 'setosa'])

df = pd.DataFrame({'sepal_length': sepal_length, 'sepal_width': sepal_width, 'petal_length': petal_length, 'petal_width': petal_width, 'SPECIES': species})
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     SPECIES
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa

# %% [markdown]
# 데이터프레임 만드는 또 다른 방법.
#
# 내용에 해당하는 부분만 판다스의 시리즈 함수를 통해서 만든다.
#
# 그러고 나서 dict를 만들어주는 것. 여기는 시리즈를 통해 내용만 5개 만들어주고, 딕트 만든다.
#
#
# 총 3가지 방법 배움
#
# 1. csv 파일 불러와서 데이터프레임으로 변화
# 2. Dict 통으로 만든다
# 3. 시리즈 써서 내용부분만 만들고 dict로.
#
# 가장 많이 이용하는 방법은 csv 파일임.

# %% [markdown]
# ### Changing column names

# %%
# Change the columns
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa

# %% [markdown]
# 특정 정보만 access하는 것도 알아야 하고, 일부의 내용을 변경하거나 수정할 필요도 있음.
#
# 대문자로 되어있는 거 바꾸고 싶다->리스트에서 바꿔서 assign.

# %% [markdown]
# ### Accessing columns

# %%
# Access one column 
df.loc[:, 'sepal_length']
# Out:
# 0    6.9
# 1    6.9
# 2    4.8
# 3    5.4
# 4    4.6
# Name: sepal_length, dtype: float64

# %% [markdown]
# loc->Location
#
# [row,column]

# %%
# Access one column (short-hand)
df['sepal_length']
# Out:
# 0    6.9
# 1    6.9
# 2    4.8
# 3    5.4
# 4    4.6
# Name: sepal_length, dtype: float64

# %%
# Access one column (shortest-hand)
df.sepal_length
# Out:
# 0    6.9
# 1    6.9
# 2    4.8
# 3    5.4
# 4    4.6
# Name: sepal_length, dtype: float64

# %% [markdown]
# 이렇게만 적어도 됨.

# %%
# Access two columns
df.loc[:, ['sepal_length', 'sepal_width']]
# Out:
#    sepal_length  sepal_width
# 0           6.9          3.2
# 1           6.9          3.1
# 2           4.8          3.4
# 3           5.4          3.0
# 4           4.6          3.6

# %% [markdown]
# 더 간단하게 적는 방법.

# %%
# Access two columns (short-hand)
df[['sepal_length', 'sepal_width']]
# Out:
#    sepal_length  sepal_width
# 0           6.9          3.2
# 1           6.9          3.1
# 2           4.8          3.4
# 3           5.4          3.0
# 4           4.6          3.6

# %% [markdown]
# 두 개의 column 가져오는 것.

# %% [markdown]
# ### Accessing rows

# %% [markdown]
# row 정보를 가져오는 것.

# %%
# Access one row 
df.loc[3, :]
# Out:
# sepal_length           5.4
# sepal_width            3.0
# petal_length           4.5
# petal_width            1.5
# species         versicolor
# Name: 3, dtype: object

# %%
# Access two rows
df.loc[[3, 0], :]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 3           5.4          3.0           4.5          1.5  versicolor
# 0           6.9          3.2           5.7          2.3   virginica

# %%
# Access a range of rows
df.loc[2:5, :]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa

# %%
# Filter keeping only rows with `sepal_length` > 5
df[df.sepal_length > 5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 3           5.4          3.0           4.5          1.5  versicolor

# %% [markdown]
# ### Accessing a cell

# %%
df.loc[:, 'sepal_length'][4]
# Out:
# 4.6

# %%
df['sepal_length'][4]
# Out:
# 4.6

# %%
df.sepal_length[4]
# Out:
# 4.6

# %% [markdown]
# ### Adding/Removing new columns

# %% [markdown]
# 어떤 컬럼을 통으로 지우거나 더하고 싶을 때.

# %%
df['new_column'] = 1
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  \
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa
#
#    new_column
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df['new_column'] = [1, 2, 3, 4, 5]
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  \
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa
#
#    new_column
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
df = df.drop('new_column', axis=1) # axis=1: column
df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           6.9          3.2           5.7          2.3   virginica
# 1           6.9          3.1           5.1          2.3   virginica
# 2           4.8          3.4           1.9          0.2      setosa
# 3           5.4          3.0           4.5          1.5  versicolor
# 4           4.6          3.6           1.0          0.2      setosa

# %% [markdown]
# 한 컬럼을 빼는 것. 뉴 칼럼은 axis 1에서 찾아라. 열에서 찾아라.
# 0이 행 정보, 1이 열 축. 거기서 drop 시켜라.

# %% [markdown]
# ### Adding/Removing new rows

# %%
df.loc[5, :] = ''
df
# Out:
#   sepal_length sepal_width petal_length petal_width     species
# 0          6.9         3.2          5.7         2.3   virginica
# 1          6.9         3.1          5.1         2.3   virginica
# 2          4.8         3.4          1.9         0.2      setosa
# 3          5.4         3.0          4.5         1.5  versicolor
# 4          4.6         3.6          1.0         0.2      setosa
# 5

# %% [markdown]
# blank string을 넣음. 블랭크로 다 들어가있다고 생각하면 됨.
#
# row도 remove할 수 있음.

# %%
df = df.drop(5, axis=0) # axis=0: row
df
# Out:
#   sepal_length sepal_width petal_length petal_width     species
# 0          6.9         3.2          5.7         2.3   virginica
# 1          6.9         3.1          5.1         2.3   virginica
# 2          4.8         3.4          1.9         0.2      setosa
# 3          5.4         3.0          4.5         1.5  versicolor
# 4          4.6         3.6          1.0         0.2      setosa
